# %%
import pandas as pd
import indicoio
import re
import requests
from elasticsearch import Elasticsearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth
import boto3
from elasticsearch import helpers


indicoio.config.api_key = 'a2b290da2dd5d95c919f3f8a1a0dcfd2'

data_df = pd.read_csv('./DataSet.csv')

# %%
# Helper function
def strip_and_tokenize(string):
    string = string.split(' ')
    string = [re.sub('[^0-9a-zA-Z]+', '', s) for s in string]
    return ' '.join(string)

def cleaner(dataframe,results):
    just_lyrics = []
    lyric_info_list = dataframe['lrc'].to_list()
    # The lyrics are stored in a list that is encasulated in a string, so using an eval() statement
    # makes sense here if this is expected behavior
    lyric_info_list= [eval(lyric) for lyric in lyric_info_list]

    # Note that a list compresention with a function could have been used here 
    for lyrics in lyric_info_list:
       just_lyrics.append([lyric['line'] for lyric in lyrics])
    just_lyrics = [' '.join(lyrics).lower() for lyrics in just_lyrics]
    just_lyrics = [strip_and_tokenize(lyrics) for lyrics in just_lyrics]
    dataframe = dataframe.join(pd.DataFrame(results))
    dataframe = dataframe.join(pd.DataFrame(just_lyrics))
    dataframe.columns = ['title','artist', 'duration','lrc', 'anger', 'fear','joy', 'sadness', 'surprise', 'cleaned_lyrics']
    dataframe.drop(['lrc'], axis=1,inplace=True)
    return dataframe
# print(indicoio.emotion(just_lyrics,top_n='6'))

# %%
# print(indicoio.emotion(just_lyrics,top_n='6'))
results = [{'joy': 0.17126202583312988, 'anger': 0.17722931504249573, 'sadness': 0.4962577223777771, 'fear': 0.1250133514404297, 'surprise': 0.03023761510848999}, {'joy': 0.07683662325143814, 'anger': 0.2904558777809143, 'sadness': 0.49546706676483154, 'fear': 0.0873340368270874, 'surprise': 0.04990643635392189}, {'joy': 0.24860981106758118, 'anger': 0.20278644561767578, 'sadness': 0.3681301176548004, 'fear': 0.15207204222679138, 'surprise': 0.028401575982570648}, {'joy': 0.03962155804038048, 'anger': 0.2806887626647949, 'sadness': 0.6279670596122742, 'fear': 0.0362224280834198, 'surprise': 0.015500245615839958}, {'joy': 0.31234413385391235, 'anger': 0.24678443372249603, 'sadness': 0.14857232570648193, 'fear': 0.2318693995475769, 'surprise': 0.060429640114307404}, {'joy': 0.1500849723815918, 'surprise': 0.06451047211885452, 'sadness': 0.2656043469905853, 'fear': 0.47904983162879944, 'anger': 0.04075036197900772}, {'joy': 0.13198763132095337, 'anger': 0.21864187717437744, 'sadness': 0.506564199924469, 'fear': 0.10418969392776489, 'surprise': 0.03861657902598381}, {'joy': 0.29782819747924805, 'anger': 0.1799919605255127, 'sadness': 0.37293004989624023, 'fear': 0.13158084452152252, 'surprise': 0.017668919637799263}, {'joy': 0.12251711636781693, 'fear': 0.22264495491981506, 'sadness': 0.41645365953445435, 'anger': 0.1739266812801361, 'surprise': 0.06445758789777756}, {'joy': 0.3142348825931549, 'fear': 0.10506579279899597, 'sadness': 0.4230797290802002, 'anger': 0.09978382289409637, 'surprise': 0.05783573538064957}, {'joy': 0.17630934715270996, 'fear': 0.07493844628334045, 'sadness': 0.6358941793441772, 'anger': 0.06467030942440033, 'surprise': 0.0481877364218235}, {'joy': 0.0978633314371109, 'anger': 0.42167890071868896, 'sadness': 0.34875574707984924, 'fear
, 'fear': 0.18480351567268372, 'surprise': 0.060852304100990295}, {'joy': 0.100044384598732, 'surprise': 0.15776681900024414, 'sadness': 0.31333833932876587, 'anger': 0.3795878291130066, 'fear': 0.0492626316845417}, {'joy': 0.07781713455915451, 'fear': 0.28179407119750977, 'sadness': 0.35269248485565186, 'anger': 0.26652875542640686, 'surprise': 0.021167542785406113}, {'joy': 0.04652978107333183, 'fear': 0.32308128476142883, 'sadness': 0.5444617867469788, 'anger': 0.06617866456508636, 'surprise': 0.019748453050851822}, {'joy': 0.13595663011074066, 'anger': 0.24298390746116638, 'sadness': 0.43568432331085205, 'fear': 0.11620333790779114, 'surprise': 0.06917178630828857}]

# %%
data = cleaner(data_df,results)

# %%
data_dict =data.to_dict(orient='records')

# %%
data.cleaned_lyrics
# Out:
# 0     gonna kick off my shoes and run in bare feet w...
# 1     yeah yeah oh its a love thing  i been working ...
# 2     are you who i be in this weekend if so lets ge...
# 3     girl you party all the time dont let me stay o...
# 4     lets go im painting im painting again im paint...
# 5     ever since you left me ive been ridin round cr...
# 6     it never ceases to blow my mind it does it to ...
# 7     instant karmas gonna get you gonna knock you r...
# 8     in my defense all my intentions were good and ...
# 9     im a lucky man yes i am living in heaven down ...
# 10    last night i fell asleep and i saw you dancing...
# 11    till my fingers blue i like countin hunnids ti...
# 12    you said this would be the very last time ill ...
# 13    damn right they got it damn right they got it ...
# 14    i need a gun to keep myself from harm the poor...
# 15    ooh yeah ill admit i was wrong what else can i...
# 16    oh far the time you and me and holiday wine wa...
# ...

# %%
data.to_csv(index=False,path_or_buf='Cleaned_data.csv')
data_json = data.to_json(orient='records')
data_json
with open('cleaned_csv_to_json.json', 'w') as f:
    f.write(data_json)

# %%
host = 'search-gifnote-kyl54r7f5kd3ehsewzr4i73elu.us-east-1.es.amazonaws.com' 
region = 'us-east-1' # e.g. us-west-1
service = 'es'
credentials = boto3.Session().get_credentials()
awsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, service)
es = Elasticsearch(
    hosts = [{'host': host, 'port': 443}],
    http_auth = awsauth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection
)

def gendata():
    
    for song in data_dict:
        yield {
            "_index": "songs",
            "_type": "document",
            "doc": song,
        }

helpers.bulk(es,gendata())
# Out:
# (99, [])

# %%
results_dictionary = es.search(index='songs',size=100)['hits']['hits']

# %%
pd.DataFrame([song['_source']['doc'] for song in results_dictionary])
# Out:
#        anger                      artist  \
# 0   0.246784               Talking Heads
# 1   0.040750               Blake Shelton
# 2   0.064670                 Keith Urban
# 3   0.151291                Charlie Puth
# 4   0.288841                The Hit Crew
# 5   0.589779                 Calum Scott
# 6   0.098911                    2 Chainz
# 7   0.386496               Frank Sinatra
# 8   0.176993                    Jessie J
# 9   0.072483                 The Beatles
# 10  0.272862                       Drake
# 11  0.089867             The Temptations
# 12  0.318486                   blink-182
# 13  0.100570                 Keith Urban
# 14  0.152100                     Kehlani
# 15  0.159385               Justin Bieber
# 16  0.138884                  Hey Violet
# 17  0.366433            Butthole Surfers
# 18  0.379588                Beastie Boys
# 19  0.266529                David Guetta
# 20  0.066179                    Coldplay
# 21  0.177229                 Keith Urban
# ...
